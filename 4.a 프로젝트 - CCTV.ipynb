# %% [markdown]
# # PYTHON PROGRAMMING

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %% [markdown]
# ## 실습 1. CCTV_in_Seoul.csv 파일을 pandas 로 읽어오세요.
# ### encoding='utf-8' 옵션을 넣습니다.

# %%
CCTV_Seoul = pd.read_csv('CCTV_in_Seoul.csv', encoding='utf-8')
data = pd.DataFrame(CCTV_Seoul)
data.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %% [markdown]
# ## 실습 2. 컬럼 중 "기관명" 컬럼명을 "구별" 로 이름을 바꾸세요.

# %%
data = data.rename(columns={'기관명':'구별'})

# %%
data
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  2780       1292    430    584    932
# 1    강동구   773        379     99    155    377
# 2    강북구   748        369    120    138    204
# 3    강서구   884        388    258    184     81
# 4    관악구  1496        846    260    390    613
# 5    광진구   707        573     78     53    174
# 6    구로구  1561       1142    173    246    323
# 7    금천구  1015        674     51    269    354
# 8    노원구  1265        542     57    451    516
# 9    도봉구   485        238    159     42    386
# 10  동대문구  1294       1070     23    198    579
# 11   동작구  1091        544    341    103    314
# 12   마포구   574        314    118    169    379
# 13  서대문구   962        844     50     68    292
# 14   서초구  1930       1406    157    336    398
# 15   성동구  1062        730     91    241    265
# 16   성북구  1464       1009     78    360    204
# 17   송파구   618        529     21     68    463
# 18   양천구  2034       1843    142     30    467
# 19  영등포구   904        495    214    195    373
# 20   용산구  1624       1368    218    112    398
# 21   은평구  1873       1138    224    278    468
# 22   종로구  1002        464    314    211    630
# 23    중구   671        413    190     72    348
# 24   중랑구   660        509    121    177    109

# %% [markdown]
# ## 실습 3. population_in_Seoul.xls 파일을 읽으세요.
# ### encoding='utf-8' 옵션을 넣습니다.

# %%
f = pd.read_excel('population_in_Seoul.xls', encoding='utf-8' )
data = pd.DataFrame(f)

# %%
data.head()
# Out:
#          기간  자치구       세대        인구     인구.1     인구.2     인구.3     인구.4  \
# 0        기간  자치구       세대        합계       합계       합계      한국인      한국인
# 1        기간  자치구       세대         계       남자       여자        계       남자
# 2  2017.1/4   합계  4202888  10197604  5000005  5197599  9926968  4871560
# 3  2017.1/4  종로구    72654    162820    79675    83145   153589    75611
# 4  2017.1/4   중구    59481    133240    65790    67450   124312    61656
#
#       인구.5    인구.6    인구.7    인구.8  세대당인구  65세이상고령자
# 0      한국인   등록외국인   등록외국인   등록외국인  세대당인구  65세이상고령자
# 1       여자       계      남자      여자  세대당인구  65세이상고령자
# 2  5055408  270636  128445  142191   2.36   1321458
# 3    77978    9231    4064    5167   2.11     25425
# 4    62656    8928    4134    4794   2.09     20764

# %%
data1 = data['자치구']['세대']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-1ced913b70f5> in <module>
# ----> 1 data1 = data['자치구']['세대']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '세대'

# %%
data1
# Out:
# (0      자치구
#  1      자치구
#  2       합계
#  3      종로구
#  4       중구
#  5      용산구
#  6      성동구
#  7      광진구
#  8     동대문구
#  9      중랑구
#  10     성북구
#  11     강북구
#  12     도봉구
#  13     노원구
#  14     은평구
#  15    서대문구
#  16     마포구
#  17     양천구
#  18     강서구
#  19     구로구
#  20     금천구
#  21    영등포구
#  22     동작구
#  23     관악구
#  24     서초구
#  25     강남구
#  26     송파구
#  27     강동구
#  28     NaN
#  Name: 자치구, dtype: object, ['세대'])

# %% [markdown]
# ## 실습 4.population_in_Seoul.xls 파일을 읽으세요.
# ### header 는 3번째 row 로 사용할 것입니다. 따라서 header = 2  로 셋팅하세요.
# ### 엑셀파일의 컬럼은  B, D, G, J, N 만 사용할 것입니다.
# ### encoding='utf-8' 옵션을 넣습니다.

# %%
data1 = data.loc[2:,['자치구','인구','인구.3','인구.6','65세이상고령자']]

# %%
data1
# Out:
#      자치구        인구     인구.3    인구.6 65세이상고령자
# 2     합계  10197604  9926968  270636  1321458
# 3    종로구    162820   153589    9231    25425
# 4     중구    133240   124312    8928    20764
# 5    용산구    244203   229456   14747    36231
# 6    성동구    311244   303380    7864    39997
# 7    광진구    372164   357211   14953    42214
# 8   동대문구    369496   354079   15417    54173
# 9    중랑구    414503   409882    4621    56774
# 10   성북구    461260   449773   11487    64692
# 11   강북구    330192   326686    3506    54813
# 12   도봉구    348646   346629    2017    51312
# 13   노원구    569384   565565    3819    71941
# 14   은평구    494388   489943    4445    72334
# 15  서대문구    327163   314982   12181    48161
# 16   마포구    389649   378566   11083    48765
# 17   양천구    479978   475949    4029    52975
# 18   강서구    603772   597248    6524    72548
# 19   구로구    447874   416487   31387    56833
# 20   금천구    255082   236353   18729    32970
# 21  영등포구    402985   368072   34913    52413
# 22   동작구    412520   400456   12064    56013
# 23   관악구    525515   507203   18312    68082
# 24   서초구    450310   445994    4316    51733
# 25   강남구    570500   565550    4950    63167
# 26   송파구    667483   660584    6899    72506
# 27   강동구    453233   449019    4214    54622
# 28   NaN       NaN      NaN     NaN      NaN

# %%
pop_Seoul = data1

# %%
pop_Seoul
# Out:
#      자치구        인구     인구.3    인구.6 65세이상고령자
# 2     합계  10197604  9926968  270636  1321458
# 3    종로구    162820   153589    9231    25425
# 4     중구    133240   124312    8928    20764
# 5    용산구    244203   229456   14747    36231
# 6    성동구    311244   303380    7864    39997
# 7    광진구    372164   357211   14953    42214
# 8   동대문구    369496   354079   15417    54173
# 9    중랑구    414503   409882    4621    56774
# 10   성북구    461260   449773   11487    64692
# 11   강북구    330192   326686    3506    54813
# 12   도봉구    348646   346629    2017    51312
# 13   노원구    569384   565565    3819    71941
# 14   은평구    494388   489943    4445    72334
# 15  서대문구    327163   314982   12181    48161
# 16   마포구    389649   378566   11083    48765
# 17   양천구    479978   475949    4029    52975
# 18   강서구    603772   597248    6524    72548
# 19   구로구    447874   416487   31387    56833
# 20   금천구    255082   236353   18729    32970
# 21  영등포구    402985   368072   34913    52413
# 22   동작구    412520   400456   12064    56013
# 23   관악구    525515   507203   18312    68082
# 24   서초구    450310   445994    4316    51733
# 25   강남구    570500   565550    4950    63167
# 26   송파구    667483   660584    6899    72506
# 27   강동구    453233   449019    4214    54622
# 28   NaN       NaN      NaN     NaN      NaN

# %%
data.head(1)
# Out:
#    기간  자치구  세대  인구 인구.1 인구.2 인구.3 인구.4 인구.5   인구.6   인구.7   인구.8  세대당인구  \
# 0  기간  자치구  세대  합계   합계   합계  한국인  한국인  한국인  등록외국인  등록외국인  등록외국인  세대당인구
#
#    65세이상고령자
# 0  65세이상고령자

# %% [markdown]
# ## 실습 5-1. pop_Seoul 의 컬럼명을 모두 출력하세요.

# %%
pop_Seoul.keys()
# Out:
# Index(['자치구', '인구', '인구.3', '인구.6', '65세이상고령자'], dtype='object')

# %% [markdown]
# ## 실습 5-2. 컬럼명을 다음처럼 바꿉니다.
# ### 0번째는 '구별' , 1번째는 '인구수', 2번쨰는 '한국인', 3번째는 '외국인', 4번째는 '고령자'  로 rename

# %% [raw]
# pop_Seoul.rename({'자치구':'구별'},{'인구':'인구수'},{'인구.3':'한국인'},{'인구.6'})

# %%
pop_Seoul.rename({'자치구':'구별'},{'인구':'인구수'},{'인구.3':'한국인'},{'인구.6':'외국인'},{'65세이상고령자':'고령자'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-e8e841d39552> in <module>
# ----> 1 pop_Seoul.rename({'자치구':'구별'},{'인구':'인구수'},{'인구.3':'한국인'},{'인구.6':'외국인'},{'65세이상고령자':'고령자'})
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     195         @wraps(func)
#     196         def wrapper(*args, **kwargs):
# --> 197             return func(*args, **kwargs)
#     198
#     199         if not PY2:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in rename(self, *args, **kwargs)
#    4018         4  3  6
#    4019         """
# -> 4020         axes = validate_axis_style_args(self, args, kwargs, 'mapper', 'rename')
#    4021         kwargs.update(axes)
#    4022         # Pop these, since the values are in `kwargs` under different names
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_validators.py in validate_axis_style_args(data, args, kwargs, arg_name, method_name)
#     319     else:
#     320         msg = "Cannot specify all of '{}', 'index', 'columns'."
# --> 321         raise TypeError(msg.format(arg_name))
#     322     return out
#     323
#
# TypeError: Cannot specify all of 'mapper', 'index', 'columns'.

# %%
a = ['구별','인구수','한국인','외국인','고령자']

# %%
pop_Seoul.head()
# Out:
#    자치구        인구     인구.3    인구.6 65세이상고령자
# 2   합계  10197604  9926968  270636  1321458
# 3  종로구    162820   153589    9231    25425
# 4   중구    133240   124312    8928    20764
# 5  용산구    244203   229456   14747    36231
# 6  성동구    311244   303380    7864    39997

# %%
a = pd.DataFrame(pop_Seoul)

# %%
pop_Seoul = a.rename(columns={'자치구':'구별','인구':'인구수','인구.3':'한국인','인구.6':'외국인','65세이상고령자':'고령자'})

# %%
pop_Seoul
# Out:
#       구별       인구수      한국인     외국인      고령자
# 2     합계  10197604  9926968  270636  1321458
# 3    종로구    162820   153589    9231    25425
# 4     중구    133240   124312    8928    20764
# 5    용산구    244203   229456   14747    36231
# 6    성동구    311244   303380    7864    39997
# 7    광진구    372164   357211   14953    42214
# 8   동대문구    369496   354079   15417    54173
# 9    중랑구    414503   409882    4621    56774
# 10   성북구    461260   449773   11487    64692
# 11   강북구    330192   326686    3506    54813
# 12   도봉구    348646   346629    2017    51312
# 13   노원구    569384   565565    3819    71941
# 14   은평구    494388   489943    4445    72334
# 15  서대문구    327163   314982   12181    48161
# 16   마포구    389649   378566   11083    48765
# 17   양천구    479978   475949    4029    52975
# 18   강서구    603772   597248    6524    72548
# 19   구로구    447874   416487   31387    56833
# 20   금천구    255082   236353   18729    32970
# 21  영등포구    402985   368072   34913    52413
# 22   동작구    412520   400456   12064    56013
# 23   관악구    525515   507203   18312    68082
# 24   서초구    450310   445994    4316    51733
# 25   강남구    570500   565550    4950    63167
# 26   송파구    667483   660584    6899    72506
# 27   강동구    453233   449019    4214    54622
# 28   NaN       NaN      NaN     NaN      NaN

# %% [markdown]
# ## 실습 6. CCTV 갯수가 가장 많은 순부터 적은 순으로 정렬한 후, 상위 20개만 화면에 보여주세요.
# ### sort_values 함수 사용하세요.

# %%
data = data.sort_values(by='소계')

# %%
data.head(20)
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년
# 9    도봉구   485        238    159     42    386
# 12   마포구   574        314    118    169    379
# 17   송파구   618        529     21     68    463
# 24   중랑구   660        509    121    177    109
# 23    중구   671        413    190     72    348
# 5    광진구   707        573     78     53    174
# 2    강북구   748        369    120    138    204
# 1    강동구   773        379     99    155    377
# 3    강서구   884        388    258    184     81
# 19  영등포구   904        495    214    195    373
# 13  서대문구   962        844     50     68    292
# 22   종로구  1002        464    314    211    630
# 7    금천구  1015        674     51    269    354
# 15   성동구  1062        730     91    241    265
# 11   동작구  1091        544    341    103    314
# 8    노원구  1265        542     57    451    516
# 10  동대문구  1294       1070     23    198    579
# 16   성북구  1464       1009     78    360    204
# 4    관악구  1496        846    260    390    613
# 6    구로구  1561       1142    173    246    323

# %%
data.tail(20)
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년
# 5    광진구   707        573     78     53    174
# 2    강북구   748        369    120    138    204
# 1    강동구   773        379     99    155    377
# 3    강서구   884        388    258    184     81
# 19  영등포구   904        495    214    195    373
# 13  서대문구   962        844     50     68    292
# 22   종로구  1002        464    314    211    630
# 7    금천구  1015        674     51    269    354
# 15   성동구  1062        730     91    241    265
# 11   동작구  1091        544    341    103    314
# 8    노원구  1265        542     57    451    516
# 10  동대문구  1294       1070     23    198    579
# 16   성북구  1464       1009     78    360    204
# 4    관악구  1496        846    260    390    613
# 6    구로구  1561       1142    173    246    323
# 20   용산구  1624       1368    218    112    398
# 21   은평구  1873       1138    224    278    468
# 14   서초구  1930       1406    157    336    398
# 18   양천구  2034       1843    142     30    467
# 0    강남구  2780       1292    430    584    932

# %%
2013년도 이전	2014년	2015년	2016년

# %% [markdown]
# ## 실습 7. 최근 3년간 CCTV 증가율을 계산하여, dataframe 에 '최근증가율' 컬럼을 추가하세요.
# ### 증가율 계산  :  (2016 + 2015 + 2014) / 2013이전 * 100

# %%
data['최근증가율'] = (data['2014년']+data['2015년']+data['2016년']) / (data['2013년도 이전']*100)

# %%
data.head()
# Out:
#      구별   소계  2013년도 이전  2014년  2015년  2016년     최근증가율
# 9   도봉구  485        238    159     42    386  0.024664
# 12  마포구  574        314    118    169    379  0.021210
# 17  송파구  618        529     21     68    463  0.010435
# 24  중랑구  660        509    121    177    109  0.007996
# 23   중구  671        413    190     72    348  0.014770

# %%
data[0:1]
# Out:
#     구별   소계  2013년도 이전  2014년  2015년  2016년     최근증가율
# 9  도봉구  485        238    159     42    386  0.024664

# %%
data.loc[9]
# Out:
# 구별                 도봉구
# 소계                 485
# 2013년도 이전          238
# 2014년              159
# 2015년               42
# 2016년              386
# 최근증가율        0.0246639
# Name: 9, dtype: object

# %%
data['소계'][1:3]
# Out:
# 12    574
# 17    618
# Name: 소계, dtype: int64

# %%
data.iloc[1:3, 1:2]
# Out:
#      소계
# 12  574
# 17  618

# %%
data[['소계', '최근증가율']]
# Out:
#       소계     최근증가율
# 9    485  0.024664
# 12   574  0.021210
# 17   618  0.010435
# 24   660  0.007996
# 23   671  0.014770
# 5    707  0.005323
# 2    748  0.012520
# 1    773  0.016649
# 3    884  0.013479
# 19   904  0.015798
# 13   962  0.004858
# 22  1002  0.024892
# 7   1015  0.010000
# 15  1062  0.008178
# 11  1091  0.013934
# 8   1265  0.018893
# 10  1294  0.007477
# 16  1464  0.006363
# 4   1496  0.014929
# 6   1561  0.006497
# 20  1624  0.005322
# 21  1873  0.008524
# 14  1930  0.006337
# 18  2034  0.003467
# 0   2780  0.015062

# %% [markdown]
# ## 실습 8. 최근 3년간 CCTV 증가율이 가장 높은 순으로 5개의 구를 찾으세요.

# %%
max_c = data.sort_values(by='최근증가율')

# %%
max_c.head()
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년     최근증가율
# 18   양천구  2034       1843    142     30    467  0.003467
# 13  서대문구   962        844     50     68    292  0.004858
# 20   용산구  1624       1368    218    112    398  0.005322
# 5    광진구   707        573     78     53    174  0.005323
# 14   서초구  1930       1406    157    336    398  0.006337

# %% [markdown]
# ## 실습 9. 서울시의 인구 데이터 중, 가장 첫번째 로우(row) 는 필요 없으니, 삭제하세요.

# %%
pop_Seoul.head()
# Out:
#     구별       인구수      한국인     외국인      고령자
# 2   합계  10197604  9926968  270636  1321458
# 3  종로구    162820   153589    9231    25425
# 4   중구    133240   124312    8928    20764
# 5  용산구    244203   229456   14747    36231
# 6  성동구    311244   303380    7864    39997

# %%
pop_Seoul = pop_Seoul.drop(2)

# %%
pop_Seoul
# Out:
#       구별     인구수     한국인    외국인    고령자
# 3    종로구  162820  153589   9231  25425
# 4     중구  133240  124312   8928  20764
# 5    용산구  244203  229456  14747  36231
# 6    성동구  311244  303380   7864  39997
# 7    광진구  372164  357211  14953  42214
# 8   동대문구  369496  354079  15417  54173
# 9    중랑구  414503  409882   4621  56774
# 10   성북구  461260  449773  11487  64692
# 11   강북구  330192  326686   3506  54813
# 12   도봉구  348646  346629   2017  51312
# 13   노원구  569384  565565   3819  71941
# 14   은평구  494388  489943   4445  72334
# 15  서대문구  327163  314982  12181  48161
# 16   마포구  389649  378566  11083  48765
# 17   양천구  479978  475949   4029  52975
# 18   강서구  603772  597248   6524  72548
# 19   구로구  447874  416487  31387  56833
# 20   금천구  255082  236353  18729  32970
# 21  영등포구  402985  368072  34913  52413
# 22   동작구  412520  400456  12064  56013
# 23   관악구  525515  507203  18312  68082
# 24   서초구  450310  445994   4316  51733
# 25   강남구  570500  565550   4950  63167
# 26   송파구  667483  660584   6899  72506
# 27   강동구  453233  449019   4214  54622
# 28   NaN     NaN     NaN    NaN    NaN

# %% [markdown]
# ## 실습 9. 서울시의 인구 데이터 중, NaN이 있는지 확인하고, NaN이 있으면 해당 row를 삭제하세요.

# %%
pop_Seoul.isnull().sum()
# Out:
# 구별     1
# 인구수    1
# 한국인    1
# 외국인    1
# 고령자    1
# dtype: int64

# %%
pop_Seoul = pop_Seoul.dropna()

# %%
pop_Seoul
# Out:
#       구별     인구수     한국인    외국인    고령자
# 3    종로구  162820  153589   9231  25425
# 4     중구  133240  124312   8928  20764
# 5    용산구  244203  229456  14747  36231
# 6    성동구  311244  303380   7864  39997
# 7    광진구  372164  357211  14953  42214
# 8   동대문구  369496  354079  15417  54173
# 9    중랑구  414503  409882   4621  56774
# 10   성북구  461260  449773  11487  64692
# 11   강북구  330192  326686   3506  54813
# 12   도봉구  348646  346629   2017  51312
# 13   노원구  569384  565565   3819  71941
# 14   은평구  494388  489943   4445  72334
# 15  서대문구  327163  314982  12181  48161
# 16   마포구  389649  378566  11083  48765
# 17   양천구  479978  475949   4029  52975
# 18   강서구  603772  597248   6524  72548
# 19   구로구  447874  416487  31387  56833
# 20   금천구  255082  236353  18729  32970
# 21  영등포구  402985  368072  34913  52413
# 22   동작구  412520  400456  12064  56013
# 23   관악구  525515  507203  18312  68082
# 24   서초구  450310  445994   4316  51733
# 25   강남구  570500  565550   4950  63167
# 26   송파구  667483  660584   6899  72506
# 27   강동구  453233  449019   4214  54622

# %% [markdown]
# ## 실습 10. '외국인비율' 과 '고령자비율' 두개의 컬럼을 추가하세요.
# ### 외국인비율 = 외국인 수 / 인구수 * 100
# ### 고령자비율 = 고령자 수 / 인구수 * 100

# %%
pop_Seoul['외국인비율'] = pop_Seoul['외국인'] / (pop_Seoul['인구수']*100)
pop_Seoul['고령자비율'] = pop_Seoul['고령자'] / (pop_Seoul['인구수']*100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
pop_Seoul
# Out:
#       구별     인구수     한국인    외국인    고령자        외국인비율       고령자비율
# 3    종로구  162820  153589   9231  25425  0.000566945  0.00156154
# 4     중구  133240  124312   8928  20764  0.000670069  0.00155839
# 5    용산구  244203  229456  14747  36231  0.000603883  0.00148364
# 6    성동구  311244  303380   7864  39997  0.000252664  0.00128507
# 7    광진구  372164  357211  14953  42214  0.000401785  0.00113428
# 8   동대문구  369496  354079  15417  54173  0.000417244  0.00146613
# 9    중랑구  414503  409882   4621  56774  0.000111483  0.00136969
# 10   성북구  461260  449773  11487  64692  0.000249035  0.00140251
# 11   강북구  330192  326686   3506  54813  0.000106181  0.00166003
# 12   도봉구  348646  346629   2017  51312  5.78524e-05  0.00147175
# 13   노원구  569384  565565   3819  71941  6.70725e-05  0.00126349
# 14   은평구  494388  489943   4445  72334  8.99091e-05   0.0014631
# 15  서대문구  327163  314982  12181  48161  0.000372322  0.00147208
# 16   마포구  389649  378566  11083  48765  0.000284435  0.00125151
# 17   양천구  479978  475949   4029  52975  8.39413e-05   0.0011037
# 18   강서구  603772  597248   6524  72548  0.000108054  0.00120158
# 19   구로구  447874  416487  31387  56833    0.0007008  0.00126895
# 20   금천구  255082  236353  18729  32970  0.000734234  0.00129253
# 21  영등포구  402985  368072  34913  52413   0.00086636  0.00130062
# 22   동작구  412520  400456  12064  56013  0.000292446  0.00135783
# 23   관악구  525515  507203  18312  68082  0.000348458  0.00129553
# 24   서초구  450310  445994   4316  51733  9.58451e-05  0.00114883
# 25   강남구  570500  565550   4950  63167   8.6766e-05  0.00110722
# 26   송파구  667483  660584   6899  72506  0.000103358  0.00108626
# 27   강동구  453233  449019   4214  54622  9.29765e-05  0.00120516

# %% [markdown]
# ## 실습 11. 외국인 대상으로 장사를 하려 합니다. 외국인이 가장 많은 구와, 외국인비율이 가장 높은 구를 각각 5개씩 찾으세요.

# %%
max_f = pop_Seoul.sort_values('외국인')
max_f.head(5)
# Out:
#      구별     인구수     한국인   외국인    고령자        외국인비율       고령자비율
# 12  도봉구  348646  346629  2017  51312  5.78524e-05  0.00147175
# 11  강북구  330192  326686  3506  54813  0.000106181  0.00166003
# 13  노원구  569384  565565  3819  71941  6.70725e-05  0.00126349
# 17  양천구  479978  475949  4029  52975  8.39413e-05   0.0011037
# 27  강동구  453233  449019  4214  54622  9.29765e-05  0.00120516

# %%
max_fr = pop_Seoul.sort_values('외국인비율')

# %%
max_fr.head(5)
# Out:
#      구별     인구수     한국인   외국인    고령자        외국인비율       고령자비율
# 12  도봉구  348646  346629  2017  51312  5.78524e-05  0.00147175
# 13  노원구  569384  565565  3819  71941  6.70725e-05  0.00126349
# 17  양천구  479978  475949  4029  52975  8.39413e-05   0.0011037
# 25  강남구  570500  565550  4950  63167   8.6766e-05  0.00110722
# 14  은평구  494388  489943  4445  72334  8.99091e-05   0.0014631

# %% [markdown]
# ## 실습 12. 고령자 대상 마케팅을 구상 중입니다. 고령자가 가장 많은 구와, 고령자비율이 가장 높은 구를 각각 5개씩 찾으세요.

# %% [markdown]
# ## 실습 13. CCTV 데이터와 인구 데이터 합치고 분석하기
# ### 아래 코드를 그대로 실행합니다.

# %% [markdown]
# ## 실습 14. data_result 에서, 다음 4개의 컬럼을 모두 버려 버립니다.
# ### '2013년도 이전', 2014년', '2015년', '2016년'

# %% [markdown]
# ## 실습 15-1. dara_result 의 인덱스를, '구별' 로 바꿔 줍니다.

# %% [markdown]
# ## 실습 15-2. 이 데이터프레임을 csv 파일로 저장합니다.
# ### 파일명은, CCTV_result.csv 입니다.

# %% [markdown]
# ## 실습 16. 상관 관계 분석에 대해서 알아봅니다.
# ### https://ko.wikipedia.org/wiki/%EC%83%81%EA%B4%80_%EB%B6%84%EC%84%9D
# ###  상관계수는 -1부터 1까지의 값을 갖는다.1일 때 완벽한 양의 상관관계가 되고, -1일 때 완벽한 음의 상관관계가 된다. 0이라면 별다른 상관관계가 없음을 의미한다.
# ###  상관계수가 0.1 이하면 관계가 없고, 0.3 이하면 약한관계 입니다

# %% [markdown]
# ## 실습 17. CCTV의 갯수와 고령자 비율의 상관관계를 분석하세요.

# %% [markdown]
# ### np.corrcoef 함수를 이용하면 됩니다.

# %% [markdown]
# ## 실습 18. CCTV의 갯수와 외국인 비율의 상관관계를 분석하세요.

# %% [markdown]
# ## 실습 19. CCTV의 갯수와 인구수의 상관관계를 분석하세요.

# %% [markdown]
# ## 실습 20. 각 구의 CCTV의 갯수를 bar로 나타내세요.
# ### pandas dataframe.plot 함수 사용

# %%
# 한글 그래프 처리 코드 실행
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
data.head()
# Out:
#      구별   소계  2013년도 이전  2014년  2015년  2016년     최근증가율
# 9   도봉구  485        238    159     42    386  0.024664
# 12  마포구  574        314    118    169    379  0.021210
# 17  송파구  618        529     21     68    463  0.010435
# 24  중랑구  660        509    121    177    109  0.007996
# 23   중구  671        413    190     72    348  0.014770

# %% [markdown]
# ## 실습 21. 각 구의 CCTV의 갯수를, 먼저 소팅(큰순)한 후,  bar로 나타내세요.

# %%
data = data.sort_values(by='소계', ascending=False)

# %%
data.head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년     최근증가율
# 0   강남구  2780       1292    430    584    932  0.015062
# 18  양천구  2034       1843    142     30    467  0.003467
# 14  서초구  1930       1406    157    336    398  0.006337
# 21  은평구  1873       1138    224    278    468  0.008524
# 20  용산구  1624       1368    218    112    398  0.005322

# %%
x = data['소계']
y = np.arange(0 , data['소계'].max())

# %%
data.plot.bar()

# %%
data.plot.bar('소계')

# %% [markdown]
# ## 실습 22. 인구 한명당 CCTV의 비율을 계산하고, 이를 각 구별로 CCTV비율이 얼마인지 bar로 나타내세요.

# %% [markdown]
# ## 실습 23. 인구수와 CCTV갯수가 어떤 분포인지, scatter로 나타내세요.

# %%
data.head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년     최근증가율
# 0   강남구  2780       1292    430    584    932  0.015062
# 18  양천구  2034       1843    142     30    467  0.003467
# 14  서초구  1930       1406    157    336    398  0.006337
# 21  은평구  1873       1138    224    278    468  0.008524
# 20  용산구  1624       1368    218    112    398  0.005322

# %%
data.plot.scatter('2016년', '소계')

# %%
size = data['소계'] / data['2016년'] * 20
city = data['구별']


plt.scatter(data['2016년'],data['소계'],s=size)


    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-20bc08c506fa> in <module>
#       7
#       8 for x,y,t in zip(data['소계'], data['2016년'], data['구별']):
# ----> 9     plt.text(x,y,t)
#      10
#      11 plt.show()
#
# TypeError: 'list' object is not callable

# %% [markdown]
# ## .실습 24. 인구수와 CCTV갯수가 약한 양의 관계가 있음을 파악했으니, 직선으로 표현하겠습니다.
